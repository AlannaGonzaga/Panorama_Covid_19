# %% [markdown]
# <a href="https://colab.research.google.com/github/AlannaGonzaga/Panorama_Covid_19/blob/main/Panorama_do_COVID_19_Brasil%2C_Portugal_e_Alemanha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Panorama do COVID 19 no Mundo com destaque nos países : Brasil, Portugal e Alemanha

# %% [markdown]
# <center><img alt="Analisando Airbnb"  src="https://static.biologianet.com/2020/01/coronavirus.jpg"></center>

# %% [markdown]
# **By: [Alanna Gonzaga](https://www.linkedin.com/in/alanna-gonzaga-10781013a/)**
#
# [GitHub](https://github.com/AlannaGonzaga) |
# [LinkedIn]((https://www.linkedin.com/in/alanna-gonzaga-10781013a/)
# | [Medium](https://medium.com/@alanna.gonzaga/)

# %% [markdown]
# COVID-19 é uma doença infecciosa causada pelo vírus SARS-CoV-2. As primeiras amostras desta doença foram encontradas na cidade de Wuhan (China) em Janeiro de 2020.
# Ele pertence a uma família de vírus que já circulava no Brasil antes da pandemia e era responsável por grande parte dos resfriados comuns.
#
# A transmissão do coronavírus ocorre facilmente entre pessoas, por meio de gotículas provenientes de tosses ou espirros de pessoas infectadas, a gravidade dos sintomas varia muito de pessoa para pessoa, por isso é importante estar atento às recomendações de higiene e isolamento social.
#
#
# <img alt="Colaboratory logo" width="50%" src="https://raw.githubusercontent.com/carlosfab/dsnp2/master/img/covid19.jpg">
#
#
# Cerca de 80% dos casos confirmados são assintomáticos e rápidos, dizem os estudos. E a grande maioria desse grupo se recupera sem nenhuma sequela.
# Entretando, 15% das pessoas têm infecções graves e precisam de oxigênio.
# Os 5% restantes são considerados casos muito graves e precisam de ventilação assistida, por meio de respiradores mecânicos em ambiente hospitalar.
#
# Com o objetivo de elevar a consciência situacional a respeito do COVID-19, irei realizar uma análise sobre os dados públicos da doença.
# Deixo o link do meu GitHub, caso queiram se aprofundar em mais detalhes.

# %% [markdown]
# # Motivação para análise
#
# A questão pela qual escolhi esses três países se dá pelo fato de ter fortes ligações familiares onde tenho interesse pessoal em acompanhar os números diários para poder saber como prevenir e contribuir no combate à pandemia.
#
# A motivação também é pelo dever cívico e pela saúde mundial.
#
#
# <img src="https://github.com/AlannaGonzaga/Images/blob/main/map002.jpg?raw=true" width=35%>

# %% [markdown]
# # Obtenção dos Dados
#
# Os dados que serão utilizados nesta análise serão vindos do portal *Our World in Data* para estudar os cenários gerais mundiais e panorama do Brasil, Portugal e Alemanha.
#
# A Organização *Our World in Data* surgiu com o intuito de tornar os **dados acessíveis** de diferentes problemas do mundo. Além da COVID-19, existem estudos sobre a fome, a pobreza, mudanças climáticas, guerras e a desigualdade social. Desta forma, esta entidade se propõe a mudar o mundo e nosso futuro através de **pesquisas** e **análise** de dados.

# %% [markdown]
# # Dicionário de Variáveis
#
#
#
# * iso_code: ISO 3166-1 alfa-3 - códigos de três letras do país;
# * continent: Continente da localização geográfica;
# * location: Localização geográfica;
# * date: Data de observação;
# * total_cases: Total de casos acumulados confirmados de COVID-19;
# * new_cases: Novos casos confirmados de COVID-19;
# * new_cases_smoothed: Média móvel de 7 dias em relação a novos casos confirmados de COVID-19;
# * total_deaths: Total de mortes acumuladas atribuídas a COVID-19;
# * new_deaths: Novas mortes atribuídas a COVID-19;
# * new_deaths_smoothed: Média móvel de 7 dias em relação a novas mortes atribuídas a COVID-19;
# * total_cases_per_million: Total de casos acumulados confirmados de COVID-19 por 1 milhão de pessoas;
# * new_cases_per_million: Novos casos confirmados de COVID-19 por 1 milhão de pessoas;
# * new_cases_smoothed_per_million: Média móvel de 7 dias em relação a novos casos confirmados de COVID-19 por 1 milhão de pessoas;
# * total_deaths_per_million: Total de mortes acumuladas atribuídas a COVID-19 por 1 milhão de pessoas:
# * new_deaths_per_million: Novas mortes atribuídas a COVID-19 por 1 milhão de pessoas;
# * new_deaths_smoothed_per_million:Média móvel de 7 dias em relação a novas mortes atribuídas a COVID-19 por 1 milhão de pessoas;
# * reproduction_rate: Estimativa em tempo real da taxa efetiva de reprodução (R) do COVID-19;
# * icu_patients: Número de pacientes COVID-19 em unidades de terapia intensiva (UTI);
# * icu_patients_per_million: Número de pacientes COVID-19 em unidades de terapia intensiva (UTI) por 1 milhão de pessoas;
# * hosp_patients: Número de pacientes COVID-19 no hospital;
# * hosp_patients_per_million: Número de pacientes COVID-19 no hospital por 1 milhão de pessoas;
# * weekly_icu_admissions: Número de pacientes COVID-19 recém-admitidos em unidades de terapia intensiva (UTI);
# * weekly_icu_admissions_per_million: Número de pacientes COVID-19 recém-admitidos em unidades de terapia intensiva (UTI) por 1 milhão de pessoas;
# * weekly_hosp_admissions: Número de pacientes COVID-19 recém-admitidos em hospitais;
# * weekly_hosp_admissions_per_million: Número de pacientes COVID-19 recém-admitidos em hospitais por 1 milhão de pessoas;
# * total_tests: Total de testes acumulados para COVID-19;
# * new_tests: Novos testes para COVID-19;
# * total_tests_per_thousand:Total de testes acumulados para COVID-19 por mil pessoas;
# * new_tests_per_thousand: Novos testes para COVID-19 por mil pessoas;
# * new_tests_smoothed: Média móvel de 7 dias de novos testes para COVID-19;
# * new_tests_smoothed_per_thousand: Média móvel de 7 dias de novos testes para COVID-19 por mil pessoas;
# * positive_rate: A parcela de testes COVID-19 que são positivos, dada como uma média contínua de 7 dias;
# * tests_per_case: Testes conduzidos por novo caso confirmado de COVID-19, dado como uma média contínua de 7 dias;
# * tests_units: Unidades usadas pelo local para relatar seus dados de teste;
# * total_vaccinations: Número total de doses de vacinação COVID-19 administradas;
# * people_vaccinated: Número total de pessoas que receberam pelo menos uma dose de vacina;
# * people_fully_vaccinated: Número total de pessoas que receberam todas as doses prescritas pelo protocolo de vacinação;
# * new_vaccinations: Novas doses de vacinação COVID-19 administradas;
# * new_vaccinations_smoothed: Média móvel de 7 dias novas doses de vacinação COVID-19 administradas;
# * total_vaccinations_per_hundred: Número total de doses de vacinação COVID-19 por 100 pessoas;
# * people_vaccinated_per_hundred: Número total de pessoas que receberam pelo menos uma dose de vacina por 100 pessoas;
# * people_fully_vaccinated_per_hundred: Número total de pessoas que receberam todas as doses prescritas pelo protocolo de vacinação por 100 pessoas;
# * new_vaccinations_smoothed_per_million: Média móvel de 7 dias em relação a Novas doses de vacinação COVID-19 administradas por 1 milhão de pessoas;
# * stringency_index: Índice de Restrição de Resposta do Governo: medida composta com base em 9 indicadores de resposta, incluindo fechamentos de escolas, fechamentos de locais de trabalho e proibições de viagens, redimensionado para um valor de 0 a 100 (100 = resposta mais restrita)
# * population: População em 2020;
# * population_density: Número de pessoas dividido por área terrestre, medido em quilômetros quadrados, ano mais recente disponível;
# * median_age: Idade média da população, projeção da ONU para 2020
# * aged_65_older: Parcela da população com 65 anos ou mais, ano mais recente disponível;
# * aged_70_older: Parcela da população com 70 anos ou mais em 2015;
# * gdp_per_capita: Produto interno bruto em paridade de poder de compra (dólares internacionais constantes de 2011), ano mais recente disponível;
# * extreme_poverty: Parcela da população que vive em pobreza extrema, ano mais recente disponível desde 2010;
# * cardiovasc_death_rate: Taxa de mortalidade por doenças cardiovasculares em 2017 (número anual de mortes por 100.000 pessoas);
# * diabetes_prevalence: Prevalência de diabetes (% da população de 20 a 79 anos) em 2017;
# * female_smokers: Parcela de mulheres que fumam, ano mais recente disponível;
# * male_smokers: Parcela de homens que fumam, ano mais recente disponível;
# * handwashing_facilities: Parcela da população com instalações básicas para lavagem das mãos no local, ano mais recente disponível;
# * hospital_beds_per_thousand: Leitos hospitalares por 1.000 pessoas, ano mais recente disponível desde 2010;
# * life_expectancy: Expectativa de vida ao nascer em 2019;
# * human_development_index: Um índice composto que mede o desempenho médio em três dimensões básicas do desenvolvimento humano - uma vida longa e saudável, conhecimento e um padrão de vida decente.

# %%
# Instalando o bar chart race
# !pip install bar_chart_race -q
# Out:
#      |████████████████████████████████| 156 kB 5.1 MB/s

# %%
# Bibliotecas necessárias:
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import bar_chart_race as bcr
import matplotlib.ticker as ticker
import seaborn as sns
import datetime as datetime
import warnings
warnings.filterwarnings('ignore')
import matplotlib.dates as mdates #para manipulação de data no matplotlib



# Exibir vídeo no colab
from IPython.display import HTML

# Importar o dataset COVID 19 para um Dataframe 
df = pd.read_csv("https://github.com/owid/covid-19-data/raw/master/public/data/owid-covid-data.csv")

# %%
dfb = df.copy()
df_covid = dfb.copy()

# %%
df_covid.set_index('date', inplace=True)

# %%
df_covid
# Out:
#            iso_code  ... excess_mortality_cumulative_per_million
# date                 ...
# 2020-02-24      AFG  ...                                     NaN
# 2020-02-25      AFG  ...                                     NaN
# 2020-02-26      AFG  ...                                     NaN
# 2020-02-27      AFG  ...                                     NaN
# 2020-02-28      AFG  ...                                     NaN
# ...             ...  ...                                     ...
# 2021-10-21      ZWE  ...                                     NaN
# 2021-10-22      ZWE  ...                                     NaN
# 2021-10-23      ZWE  ...                                     NaN
# 2021-10-24      ZWE  ...                                     NaN
# 2021-10-25      ZWE  ...                                     NaN
#
# [126167 rows x 64 columns]

# %% [markdown]
# Extraindo e definindo as bases que serão utilizadas

# %%
base_brasil = dfb[dfb['location']=='Brazil']
base_alemanha = dfb[dfb['location']=='Germany']
base_portugal = dfb[dfb['location']=='Portugal']

# %% [markdown]
# # Análise Exploratória dos Dados
#
# <img src="https://www.cfrinc.net/hubfs/data%20analysis%20techniques%20for%20market%20research.jpg" width=35%>
#
#
#
#
#
#
# Com os dados obtidos, vamos analisar os três países ( Brasil, Portugal e Alemanha ) e mostrar os seguintes indicadores:
#
# * Número de casos/infecção;
# * Evolução da Pandemia;
# * Taxa de mortalidade;
# * Vacinação

# %%
# Visualizar a cinco primeiras linhas do Dataset
df.head(5)
# Out:
#   iso_code continent  ... excess_mortality excess_mortality_cumulative_per_million
# 0      AFG      Asia  ...              NaN                                     NaN
# 1      AFG      Asia  ...              NaN                                     NaN
# 2      AFG      Asia  ...              NaN                                     NaN
# 3      AFG      Asia  ...              NaN                                     NaN
# 4      AFG      Asia  ...              NaN                                     NaN
#
# [5 rows x 65 columns]

# %%
# Resumo geral do Dataset
print('Este dataset contém:')
print('{:,} entradas'.format(df.shape[0]).replace(',','.'))
print('{} Variáveis'.format(df.shape[1]))
print('Sendo o index das tabelas as datas de registro')
# Out:
# Este dataset contém:
# 126.167 entradas
# 65 Variáveis
# Sendo o index das tabelas as datas de registro

# %%
# Nomes das colunas no Dataset
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
#exibindo todas as linhas para poder verificar o dataset
pd.set_option('display.max_rows',None)

# Tipos de variáveis no Dataset
pd.DataFrame(df.dtypes, columns=['Tipo de Dados'])
# Out:
#                                         Tipo de Dados
# iso_code                                       object
# continent                                      object
# location                                       object
# date                                           object
# total_cases                                   float64
# new_cases                                     float64
# new_cases_smoothed                            float64
# total_deaths                                  float64
# new_deaths                                    float64
# new_deaths_smoothed                           float64
# total_cases_per_million                       float64
# new_cases_per_million                         float64
# new_cases_smoothed_per_million                float64
# total_deaths_per_million                      float64
# new_deaths_per_million                        float64
# new_deaths_smoothed_per_million               float64
# ...

# %%
#retornando a exibir menos linhas
pd.set_option('display.max_rows',10)

# Verificando os campos nulos que podem comprometer a análise do dataset
df_continent_empty = df[['continent','location']]
df_continent_empty[df_continent_empty['continent'].isna()]
# Out:
#        continent location
# 610          NaN   Africa
# 611          NaN   Africa
# 612          NaN   Africa
# 613          NaN   Africa
# 614          NaN   Africa
# ...          ...      ...
# 124426       NaN    World
# 124427       NaN    World
# 124428       NaN    World
# 124429       NaN    World
# 124430       NaN    World
#
# [5713 rows x 2 columns]

# %% [markdown]
# Percebe-se que algumas localidades aparece a palavra "NaN" ou seja, está vazia. Para evitar que esses valores possam comprometer nossa análise, iremos retira-los da base.

# %%
#países sem os continentes na lista
df_lista_sem_continentes = df[~df['continent'].isna()]

# %%
df_lista_sem_continentes.set_index('date', inplace=True)

# %%
df_lista_sem_continentes.head()
# Out:
#            iso_code  ... excess_mortality_cumulative_per_million
# date                 ...
# 2020-02-24      AFG  ...                                     NaN
# 2020-02-25      AFG  ...                                     NaN
# 2020-02-26      AFG  ...                                     NaN
# 2020-02-27      AFG  ...                                     NaN
# 2020-02-28      AFG  ...                                     NaN
#
# [5 rows x 64 columns]

# %%
# Resumo geral do Dataset
print('Este dataset contém:')
print('{:,} entradas'.format(df_lista_sem_continentes.shape[0]).replace(',','.'))
print('{} Variáveis'.format(df_lista_sem_continentes.shape[1]))
print('Sendo o index das tabelas as datas de registro')
# Out:
# Este dataset contém:
# 120.454 entradas
# 64 Variáveis
# Sendo o index das tabelas as datas de registro

# %%
#criando o figure e o ax no matplotlib
fig,ax = plt.subplots(figsize=(20,12),nrows=2,ncols=1)

#Avaliando os 15 paises tem mais casos no dia 20/10/2021
dia = '20/10/2021'

#preparando os dados dos países com mais casos
df_paises_com_mais_casos = df_lista_sem_continentes.loc['2021-09-30'][['location','total_cases']].sort_values(
    by='total_cases',ascending=False)[:15]

#ajustando os parâmetros para o primeiro gráfico
ax[0].bar(data=df_paises_com_mais_casos,x='location',height='total_cases',color='brown')
ax[0].set_title('Casos acumulados de COVID-19 até 20/10/2021',loc='left',pad=30,fontdict={'fontsize':24, 'Family': 'serif'})
ax[0].bar(data=df_paises_com_mais_casos[df_paises_com_mais_casos['location'] == 'Brazil'],x='location',height='total_cases',color=(0.2, 0.4, 0.6, 0.6))
ax[0].bar(data=df_paises_com_mais_casos[df_paises_com_mais_casos['location'] == 'Germany'],x='location',height='total_cases',color=(0.2, 0.4, 0.6, 0.6))
ax[0].tick_params(axis='x',labelsize=10,pad=10,rotation=10)

#preparando os dados dos países com mais mortes
df_paises_com_mais_mortes = df_lista_sem_continentes.loc['2021-09-30'][['location','total_deaths']].sort_values(
    by='total_deaths',ascending=False)[:15]



#ajustando os parâmetros para o segundo gráfico
ax[1].bar(data=df_paises_com_mais_mortes,x='location',height='total_deaths',color='brown')
ax[1].set_title('Casos de mortes relacionadas a COVID-19 acumuladas até 20/10/2021',loc='left',pad=30,fontdict={'fontsize':24,'Family':'serif'})
ax[1].bar(data=df_paises_com_mais_mortes[df_paises_com_mais_mortes['location'] == 'Brazil'],x='location',height='total_deaths',color=(0.2, 0.4, 0.6, 0.6))
ax[1].bar(data=df_paises_com_mais_mortes[df_paises_com_mais_mortes['location'] == 'Germany'],x='location',height='total_deaths',color=(0.2, 0.4, 0.6, 0.6))
ax[1].tick_params(axis='x',labelsize=10,pad=10,rotation=10)


#plotando os gráficos
plt.tight_layout()

# %% [markdown]
# Listamos os primeiros 15 países para o primeiro e segundo gráfico e notamos alguns pontos, são eles;
#
# - México em números de casos esteve na ultima posição de nosso gráfico porem em números de mortes pulou para 4. posição.
#
# - Esse estudo será direcionado para os países : Brasil, Alemanha e Portugal, como podem observar, Portugal não aparece na lista dos 15 países de casos e de mortes.
#
# - Africa do Sul também aparece na lista dos 15 países com mais mortes porém não aparece em números de casos.

# %% [markdown]
# # Evolução da curva epidêmica
#
#
#
# <img src="https://images.pexels.com/photos/3994840/pexels-photo-3994840.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500" width=35%>
#
#
# Uma das maiores preocupações das organizações de saúde é a progressão do número de casos e mortes no mundo.
#
# Uma das melhores formas de visualizarmos a evolução ao longo do tempo, é o gráfico de linhas. Por isso, vamos plotar um gráfico de linha para demonstrar e evolução de mortes no mundo e tambem separado por Brasil, Alemanha e Portugal.

# %%
# Criar uma cópia do DataFrame apenas com o Brasil
df_brasil = df_lista_sem_continentes.loc[df_lista_sem_continentes.location == "Brazil"].copy()

df_brasil.head()
# Out:
#            iso_code  ... excess_mortality_cumulative_per_million
# date                 ...
# 2020-02-26      BRA  ...                                     NaN
# 2020-02-27      BRA  ...                                     NaN
# 2020-02-28      BRA  ...                                     NaN
# 2020-02-29      BRA  ...                               32.943066
# 2020-03-01      BRA  ...                                     NaN
#
# [5 rows x 64 columns]

# %%
# Criar uma cópia do DataFrame apenas com Alemanha
df_alemanha = df_lista_sem_continentes.loc[df_lista_sem_continentes.location == "Germany"].copy()

df_alemanha.head()
# Out:
#            iso_code  ... excess_mortality_cumulative_per_million
# date                 ...
# 2020-01-27      DEU  ...                                     NaN
# 2020-01-28      DEU  ...                                     NaN
# 2020-01-29      DEU  ...                                     NaN
# 2020-01-30      DEU  ...                                     NaN
# 2020-01-31      DEU  ...                                     NaN
#
# [5 rows x 64 columns]

# %%
# Criar uma cópia do DataFrame apenas com Portugal
df_portugal = df_lista_sem_continentes.loc[df_lista_sem_continentes.location == "Portugal"].copy()

df_portugal.head()
# Out:
#            iso_code  ... excess_mortality_cumulative_per_million
# date                 ...
# 2020-01-06      PRT  ...                                     NaN
# 2020-01-18      PRT  ...                                     NaN
# 2020-01-24      PRT  ...                                     NaN
# 2020-02-02      PRT  ...                              -90.834677
# 2020-02-09      PRT  ...                             -111.350174
#
# [5 rows x 64 columns]

# %%
#convertendo a variável date para datetime
base_brasil['date'] = pd.to_datetime(base_brasil['date'])
base_alemanha['date'] = pd.to_datetime(base_alemanha['date'])
base_portugal['date'] = pd.to_datetime(base_portugal['date'])

# %%
países_3 = df.copy()

# %%
países_3.head()
# Out:
#   iso_code continent  ... excess_mortality excess_mortality_cumulative_per_million
# 0      AFG      Asia  ...              NaN                                     NaN
# 1      AFG      Asia  ...              NaN                                     NaN
# 2      AFG      Asia  ...              NaN                                     NaN
# 3      AFG      Asia  ...              NaN                                     NaN
# 4      AFG      Asia  ...              NaN                                     NaN
#
# [5 rows x 65 columns]

# %%
# selecionar os 3 países do estudo com o maior número de mortes
países_3 = df.copy()
países_3.set_index('location', inplace = True)
países_3 = países_3.loc[['Brazil', 'Germany', 'Portugal']]
países_3 = países_3.reset_index()
países_3.date = pd.to_datetime(países_3.date)

# plotar o gráfico de linha
fig, ax = plt.subplots(figsize=(15,7))

ax = sns.lineplot(x='date', y="total_deaths", hue="location", data=países_3);
ax.set_xlabel("Data")
ax.set_ylabel("Número de mortes")
ax.set_title("Total de mortes por país")

plt.tight_layout()

# %%
# selecionar os 3 países do estudo com o maior número de mortes
países_3 = df.copy()
países_3.set_index('location', inplace = True)
países_3 = países_3.loc[['Brazil', 'Germany', 'Portugal']]
países_3 = países_3.reset_index()
países_3.date = pd.to_datetime(países_3.date)

# plotar o gráfico de linha
fig, ax = plt.subplots(figsize=(15,7))

ax = sns.lineplot(x='date', y="total_deaths_per_million", hue="location", data=países_3);
ax.set_xlabel("Data")
ax.set_ylabel("Número de mortes")
ax.set_title("Óbitos por milhão de habitantes - Brasil x Alemanha x Portugal")

plt.tight_layout()

# %% [markdown]
# É evidente a curva acentuada de Portugal perante os outros países entre o final de 2020 ao início de 2021.
# Portugal saiu de exemplo para o caos na gestão da saúde onde perdeu o controle da pandemia recorrendo a pedido de ajuda internacional.

# %% [markdown]
# <img src="http://c.files.bbci.co.uk/8C12/production/_111785853_portugalgettyimages-1208205986.jpg" width=35%>

# %% [markdown]
# Para rodar o código abaixo será necessário aproximadamente cerca de 20 minutos pois trata-se de um dataset com tamanho elevado além de ser compilado e transformado em gráficos dinâmicos.

# %%
import bar_chart_race as bcr

# %%
#bar chart do número de mortos ao longo do tempo

#separando os dados para colocar no pacote do bar chart race
dados_bar_chart = df_lista_sem_continentes.pivot_table(index='date',columns='location',values='total_deaths')

#plotando um bar chart race customizado
bcr.bar_chart_race(
    df=dados_bar_chart, # selecionando os dados
    filename='covid_paises_mortes.mp4', # nomeando o arquivo
    orientation='h', # orientação do gráfico
    sort='desc', # organização 
    n_bars=10, # número de barras
    fixed_order=False, # ordem fixa
    fixed_max=True, # máximo fixo
    steps_per_period= 10, # steps por período
    interpolate_period=False, # interpolar o período
    label_bars=True, # colocar labels nas barras
    bar_size=.75, # tamanho da barra
    period_label={'x': .99, 'y': .25, 'ha': 'right', 'va': 'center'}, # labels dos períodos
    period_fmt='%B %d, %Y', # formato do período
    period_length=80,# tamanho do período
    figsize=(5, 3), 
    dpi=144, 
    cmap='dark12', # esquema de cores
    title='Mortes por COVID-19 ao longo do tempo', # título
    title_size='', # tamamnho do título
    bar_label_size=7, # tamanho do label das barras
    tick_label_size=7, # tamanho do tick do label
    scale='linear', # escala dos dados
    filter_column_colors=False);  # filtrar cores das colunas

# %%
#visualizar o vídeo no google colab
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/OkqrB-knQQE" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/OkqrB-knQQE" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
#criando o figure e o ax no matplotlib
fig,ax = plt.subplots(figsize=(12,8))

#parâmetros do gráfico
ax.set_title('Redução de casos com a vacinação no Brasil',loc='left',pad=25,fontdict={'fontsize':24,'family':'serif'})
países_3[países_3.location =='Brazil'].plot(x='date', y='new_deaths_smoothed', ax=ax)
países_3[países_3.location =='Brazil'].plot(x='date', y='new_vaccinations_smoothed_per_million', ax=ax)
ax.legend(['Média Móvel de mortos','Média Móvel de vacinados por milhão'],frameon=False,fontsize=14,loc='top')


#plotando os gráficos
ax.grid(linestyle='-.',lw=0.4,aa=True)
ax.set_frame_on(False)
plt.tight_layout();

# %%
#criando o figure e o ax no matplotlib
fig,ax = plt.subplots(figsize=(12,8))


#parâmetros do gráfico
ax.set_title('Redução de casos com a vacinação na Alemanha',loc='left',pad=25,fontdict={'fontsize':24,'family':'serif'})
países_3[países_3.location =='Germany'].plot(x='date', y='new_deaths_smoothed', ax=ax)
países_3[países_3.location =='Germany'].plot(x='date', y='new_vaccinations_smoothed_per_million', ax=ax)
ax.legend(['Média Móvel de mortos','Média Móvel de vacinados por milhão'],frameon=False,fontsize=14,loc='top')


#plotando os gráficos
ax.grid(linestyle='-.',lw=0.4,aa=True)
ax.set_frame_on(False)
plt.tight_layout();

# %%
#criando o figure e o ax no matplotlib
fig,ax = plt.subplots(figsize=(12,8))


#parâmetros do gráfico
ax.set_title('Redução de casos com a vacinação em Portugal',loc='left',pad=25,fontdict={'fontsize':24,'family':'serif'})
países_3[países_3.location =='Portugal'].plot(x='date', y='new_deaths_smoothed', ax=ax)
países_3[países_3.location =='Portugal'].plot(x='date', y='new_vaccinations_smoothed_per_million', ax=ax)
ax.legend(['Média Móvel de mortos','Média Móvel de vacinados por milhão'],frameon=False,fontsize=14,loc='top')



#plotando os gráficos
ax.grid(linestyle='-.',lw=0.4,aa=True)
ax.set_frame_on(False)
plt.tight_layout();

# %% [markdown]
# Nos três países observados é possível visualizar como a vacinação auxiliou na diminuição de mortes, em especial no Brasil.
#
# A pandemia foi um problema que foi enfrentado de diversas formas em toda a parte do mundo, porém, é sabido que no caso do Brasil, houve medidas "leves" nesse combate, por diversos motivos, principalmente  no quesito político, onde o principal representante desestimulava a eficácia e se mostrou antivacinas desde o desenvolvimento do imunizante contra o coronavírus.

# %% [markdown]
# # Conclusão
#
# <img src="https://www.solidaridadnetwork.org/wp-content/uploads/migrated-files/uploads/Screen%20Shot%202020-05-26%20at%2012.28.39%20PM.png" width=35%>

# %% [markdown]
# Neste estudo utilizamos o dataset para estudo de uma perspectiva enfatizando três países, Alemanha, Brasil e Portugal, aos quais tenho fortes laços familiares, onde tenho interesse pessoal no acompanhamento dos números divulgados pelo meu interesse em acompanhar os dados divulgados pela organização  [Our World in Data](https://ourworldindata.org/about)
# .
#
# Diante disso, concluímos que:
#
# - O Brasil, segundo lugar no ranking mundial, com os piores resultados de controle contra o Covid-19. É notório que a vacinação e a influencia e resistencia dos líderes políticos influenciaram com medidas flexíveis à população;
#
# - Em Portugal, iniciou com exemplo no combate à pandemia porém seguiu uma política menos restritiva que levou ao caos. A estratégia foi alterada e os números voltaram a reduzir a contaminação do coronavírus.
#
# - A Alemanha desde o início da pandemia teve uma mistura de medidas muito brandas, com demora em reagir mesmo com o apelo de Angela Merkel que agiu fortemente no modelo de prevenção no combate à pandemia. A Alemanha foi um dos países mais golpeados pella covid-19 na Europa.
#
# Infelizmente o vírus ainda não está controlado nem a pandemia vencida, conclui a OMS. Os dados mostram que a vacinação pode ter influencia diretamente nos índices de mortalidade.
# Além disso, apesar de as vacinas serem uma ferramenta essencial, outras armas devem ser usadas contra o novo coronavírus, com os mesmos cuidados pregados no início de 2020 ainda ainda valem: distanciamento social, higiene das mãos, uso de máscara e ventilação dos ambientes.
#
# Qualquer dúvida, entre em contato!
#
# Obrigada pela leitura!
